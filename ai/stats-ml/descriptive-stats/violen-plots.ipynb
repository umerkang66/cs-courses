# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
n = 1000
thresh = 5

data = np.exp(np.random.randn(n)/2)
data[data>thresh] = thresh + np.random.randn(sum(data>thresh))*.1

plt.plot(data, 'o')
plt.show()

# %%
plt.hist(data, bins=30)
plt.title("Histogram of Data")
plt.show()

plt.violinplot(data)
plt.title("Violen Plot")
plt.show()

# %%
import seaborn as sns
sns.violinplot(data)
plt.title("By Seaborn")
plt.show()

# %%
sns.swarmplot(data, orient='v')
plt.show()
# Out:
# /home/umerkang/Workspace/cs-courses/ai/stats-ml/stats-env/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning: 7.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
